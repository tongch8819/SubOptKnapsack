# %% [markdown]
# corresponding to archive-45

# %%
import pickle
import os
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import math

# %%
t = 'T'

def load_12_series(upper_bound: str, task_name: str, source_dir: str):
    """
    kv_data has the following keys: 
    - 'S'
    - 'f(S)'
    - 'c(S)'
    - 'Lambda'
    - 'AF'
    """
    task_dict = {
        "facebook": "FacebookGraphCoverage",
        "youtube" : "YoutubeCoverage",
        "caltech": "CalTechMaximization",
        "adult": "AdultIncomeFeatureSelection"
    }

    res = []
    # print(f"r:{source_dir}")
    for name in os.listdir(source_dir):
        # print(f"name:{name}")
        if not os.path.isdir(os.path.join(source_dir, name)):
            up, task, budget, _ = name.strip()[:-5].split('-')
            # algo, up, task, b = name.strip()[:-5].split('-')
            # print(f"u:{upper_bound}, t:{task_name}, up:{up}, task:{task}")
            
            if up == upper_bound and task_dict[task_name] == task:
                # print(name)
                file_path = os.path.join(source_dir, name)
                with open(file_path, "rb") as rd:
                    kv_data = pickle.load(rd)
                # print(kv_data)
                if t == 'T':
                    res.append( (eval(budget), kv_data['f(S)'], kv_data['upb'], kv_data['time']))
                elif t == '':
                    res.append( (eval(budget), kv_data['f(S)'], kv_data['upb'], kv_data['AF']))      
                elif t == 'W':
                    res.append( (eval(budget), kv_data['f(S)'], kv_data['upb'], kv_data['AF']/kv_data['worst']))      
    res = sorted(res, key=lambda x: x[0])
    # print(res)
    X, Y, Z, W = list(zip(*res))   # change it to two columns
    return X, Y, Z, W

task_list = ['facebook']

ub_list = [
    'lbd0u', 'lbd1u', 'lbd2u', 'lbd3u'
]

ub_title_dict = {
    'lbd0': r"$\Psi^{0}$",
    'lbd1': r"$\Psi^{1}$",
    'lbd2': r"$\Psi^{2}$",
    'lbd3': r"$\Psi^{3}$",
    'lbd0u': r"$\Psi^{0*}$",
    'lbd1u': r"$\Psi^{1*}$",
    'lbd2u': r"$\Psi^{2*}$",
    'lbd3u': r"$\Psi^{3*}$",
}

ub_title_list = [ub_title_dict[ub] for ub in ub_list]

archive_dir = "../result/archive-57"

result_dir = "./result_min_50"

n = 1000
worst_case = math.log(n, math.e)
fs = 48

u_data_list = []
for ub in ub_list:
    u_data_list.append([])

seed_range = range(0, 20)
# b_range = range(15, 65, 5)
b_range = range(250, 500, 25)

b_data_list = []
for ub in ub_list:
    temp = []
    for v in b_range:
        temp.append([])
    b_data_list.append(temp)
bti_dict = {}
for i in range(0, len(b_range)):
    b = float(b_range[i])
    bti_dict[b] = i

ub_to_draw_list = [0, 3]

count = 0
total_count = len(task_list) + len(ub_list) * len(task_list)

for task in task_list:
    for seed in seed_range:
        for ub_idx in range(0, len(ub_list)):
            # print(f"seed:{seed}")
            ub = ub_list[ub_idx]
            source_dir = os.path.join(archive_dir, f"{task}", f"{n}", f"{seed}")
            # print(f"seed:{seed}")
            X, Y, Z, W = load_12_series(upper_bound=ub, task_name=task, source_dir=source_dir)

            for x_idx in range(0, len(X)):
                b = X[x_idx]
                if int(b) in b_range:
                    b_list_idx = bti_dict[b]
                    b_data_list[ub_idx][b_list_idx].append(W[x_idx])    
                    u_data_list[ub_idx].append(W[x_idx])
                    # if W[x_idx] > 1.1:
                    #     print(f"seed:{seed}, v:{X[x_idx]}")

    # first plot
    data = u_data_list

    plt.rcParams["font.size"] = fs
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_axes([0,0,1,1])
    if t == '':
        ax.set_ylabel("Approximation guarantee")
    elif t == 'T':
        ax.set_ylabel("Computational time (s)")
    elif t == 'W':
        ax.set_ylabel("Ratio")

    box_props = dict(linewidth=1.5, color="black")
    median_props = dict(linewidth=2)

    for ub_idx in range(0, len(ub_list)):
        ub = ub_list[ub_idx]
        print(f"ub:{ub}, mean:{np.mean(data[ub_idx])}")

    bp = ax.boxplot(data, patch_artist=True, showfliers=True, tick_labels=ub_title_list, showmeans=True, boxprops=box_props, medianprops=median_props)
    # plt.axhline(y = worst_case, color = 'r', linestyle = '-') 
    
    ax.plot()

    plt.xticks(fontsize=fs) 

    for median in bp["medians"]:
        median.set_color("black")

    for box in bp["boxes"]:
        box.set_facecolor("whitesmoke")


    suffix = ""
    if t != '':
        suffix= "_" + t

    plt.savefig(os.path.join(result_dir, f"{task}_{n}{suffix}.pdf"), format='pdf', bbox_inches='tight')
    plt.savefig(os.path.join(result_dir, f"{task}_{n}{suffix}.jpg"), format='jpg', bbox_inches='tight')
    count = count + 1
    print(f"count:{count}/{total_count} {task}_{n}{suffix}.pdf completed.")

    # second plot

    fig = plt.figure(figsize=(10, 8))

    ax = fig.add_axes([0,0,1,1])
    ax.set_ylabel("Approximation factor")
    # ax.set_ylabel("Computational time(s)")

    box_props = dict(linewidth=1.5, color="black")
    median_props = dict(linewidth=2)
    mean_props = {"marker":"^","markerfacecolor":"darkgreen", "markeredgecolor":"darkgreen"}
    flier_props = {"marker":"o","markerfacecolor":"darkgreen", "markeredgecolor":"black"}
    flier_props = {"marker":"o","markerfacecolor":"darkgreen", "markeredgecolor":"black"}
    whisker_props = {"color":"black"}

    color_list = ["whitesmoke","wheat", 'cornsilk']

    whisker_color_list = ["dimgray","orange",'cornsilk']
    cc = 0

    for i in ub_to_draw_list:
        data = b_data_list[i]
        ub = ub_list[i]

        flier_props["markerfacecolor"] = color_list[cc]
        whisker_props["color"] = whisker_color_list[cc]

        xtick_labels = []
        for b in b_range:
            if int(b) % 2 == 1:
                xtick_labels.append(b)
            else:
                xtick_labels.append(" ")

        bp = ax.boxplot(data,label=ub_title_dict[ub], patch_artist=True, tick_labels=xtick_labels, showmeans=True, boxprops=box_props, medianprops=median_props
                        , meanprops=mean_props, flierprops=flier_props, whiskerprops=whisker_props, capprops=whisker_props)
        # plt.axhline(y = worst_case, color = 'r', linestyle = '-') 

        for median in bp["medians"]:
            median.set_color("black")
        for box in bp["boxes"]:
            box.set_facecolor(color_list[cc])

        cc = cc + 1

        plt.legend()
        plt.savefig(os.path.join(result_dir, f"{task}_{n}_v{suffix}.jpg"), format='jpg', bbox_inches='tight')
        plt.savefig(os.path.join(result_dir, f"{task}_{n}_v{suffix}.pdf"), format='pdf', bbox_inches='tight')
        count = count + 1
        print(f"count:{count}/{total_count} {task}_v.jpg completed.")
# Out:
# seed:0, v:15.0
# seed:0, v:20.0
# seed:0, v:25.0
# seed:0, v:30.0
# seed:0, v:35.0
# seed:0, v:40.0
# seed:0, v:45.0
# seed:0, v:50.0
# seed:0, v:55.0
# seed:0, v:60.0
# seed:0, v:15.0
# seed:0, v:20.0
# seed:0, v:25.0
# seed:0, v:30.0
# seed:0, v:35.0
# seed:0, v:40.0
# seed:0, v:45.0
# seed:0, v:50.0
# seed:0, v:55.0
# seed:0, v:60.0
# seed:0, v:15.0
# seed:0, v:20.0
# seed:0, v:25.0
# seed:0, v:30.0
# seed:0, v:35.0
# seed:0, v:40.0
# seed:0, v:45.0
# seed:0, v:50.0
# seed:0, v:55.0
# seed:0, v:60.0
# seed:0, v:15.0
# seed:0, v:20.0
# seed:0, v:25.0
# seed:0, v:30.0
# seed:0, v:35.0
# seed:0, v:40.0
# seed:0, v:45.0
# seed:0, v:50.0
# seed:0, v:55.0
# seed:0, v:60.0
# seed:1, v:15.0
# seed:1, v:20.0
# seed:1, v:25.0
# seed:1, v:30.0
# seed:1, v:35.0
# seed:1, v:40.0
# seed:1, v:45.0
# seed:1, v:50.0
# seed:1, v:55.0
# seed:1, v:60.0
# seed:1, v:15.0
# seed:1, v:20.0
# seed:1, v:25.0
# seed:1, v:30.0
# seed:1, v:35.0
# seed:1, v:40.0
# seed:1, v:45.0
# seed:1, v:50.0
# seed:1, v:55.0
# seed:1, v:60.0
# seed:1, v:15.0
# seed:1, v:20.0
# seed:1, v:25.0
# seed:1, v:30.0
# seed:1, v:35.0
# seed:1, v:40.0
# seed:1, v:45.0
# seed:1, v:50.0
# seed:1, v:55.0
# seed:1, v:60.0
# seed:1, v:15.0
# seed:1, v:20.0
# seed:1, v:25.0
# seed:1, v:30.0
# seed:1, v:35.0
# seed:1, v:40.0
# seed:1, v:45.0
# seed:1, v:50.0
# seed:1, v:55.0
# seed:1, v:60.0
# seed:2, v:15.0
# seed:2, v:20.0
# seed:2, v:25.0
# seed:2, v:30.0
# seed:2, v:35.0
# seed:2, v:40.0
# seed:2, v:45.0
# seed:2, v:50.0
# seed:2, v:55.0
# seed:2, v:60.0
# seed:2, v:15.0
# seed:2, v:20.0
# seed:2, v:25.0
# seed:2, v:30.0
# seed:2, v:35.0
# seed:2, v:40.0
# seed:2, v:45.0
# seed:2, v:50.0
# seed:2, v:55.0
# seed:2, v:60.0
# seed:2, v:15.0
# seed:2, v:20.0
# seed:2, v:25.0
# seed:2, v:30.0
# seed:2, v:35.0
# seed:2, v:40.0
# seed:2, v:45.0
# seed:2, v:50.0
# seed:2, v:55.0
# seed:2, v:60.0
# seed:2, v:15.0
# seed:2, v:20.0
# seed:2, v:25.0
# seed:2, v:30.0
# seed:2, v:35.0
# seed:2, v:40.0
# seed:2, v:45.0
# seed:2, v:50.0
# seed:2, v:55.0
# seed:2, v:60.0
# seed:3, v:15.0
# seed:3, v:20.0
# seed:3, v:25.0
# seed:3, v:30.0
# seed:3, v:35.0
# seed:3, v:40.0
# seed:3, v:45.0
# seed:3, v:50.0
# seed:3, v:55.0
# seed:3, v:60.0
# seed:3, v:15.0
# seed:3, v:20.0
# seed:3, v:25.0
# seed:3, v:30.0
# seed:3, v:35.0
# seed:3, v:40.0
# seed:3, v:45.0
# seed:3, v:50.0
# seed:3, v:55.0
# seed:3, v:60.0
# seed:3, v:15.0
# seed:3, v:20.0
# seed:3, v:25.0
# seed:3, v:30.0
# seed:3, v:35.0
# seed:3, v:40.0
# seed:3, v:45.0
# seed:3, v:50.0
# seed:3, v:55.0
# seed:3, v:60.0
# seed:3, v:15.0
# seed:3, v:20.0
# seed:3, v:25.0
# seed:3, v:30.0
# seed:3, v:35.0
# seed:3, v:40.0
# seed:3, v:45.0
# seed:3, v:50.0
# seed:3, v:55.0
# seed:3, v:60.0
# seed:4, v:20.0
# seed:4, v:25.0
# seed:4, v:30.0
# seed:4, v:35.0
# seed:4, v:40.0
# seed:4, v:45.0
# seed:4, v:50.0
# seed:4, v:55.0
# seed:4, v:60.0
# seed:4, v:20.0
# seed:4, v:25.0
# seed:4, v:30.0
# seed:4, v:35.0
# seed:4, v:40.0
# seed:4, v:45.0
# seed:4, v:50.0
# seed:4, v:55.0
# seed:4, v:60.0
# seed:4, v:15.0
# seed:4, v:20.0
# seed:4, v:25.0
# seed:4, v:30.0
# seed:4, v:35.0
# seed:4, v:40.0
# seed:4, v:45.0
# seed:4, v:50.0
# seed:4, v:55.0
# seed:4, v:60.0
# seed:4, v:15.0
# seed:4, v:20.0
# seed:4, v:25.0
# seed:4, v:30.0
# seed:4, v:35.0
# seed:4, v:40.0
# seed:4, v:45.0
# seed:4, v:50.0
# seed:4, v:55.0
# seed:4, v:60.0
# seed:5, v:20.0
# seed:5, v:25.0
# seed:5, v:30.0
# seed:5, v:35.0
# seed:5, v:40.0
# seed:5, v:45.0
# seed:5, v:50.0
# seed:5, v:55.0
# seed:5, v:60.0
# seed:5, v:15.0
# seed:5, v:20.0
# seed:5, v:25.0
# seed:5, v:30.0
# seed:5, v:35.0
# seed:5, v:40.0
# seed:5, v:45.0
# seed:5, v:50.0
# seed:5, v:55.0
# seed:5, v:60.0
# seed:5, v:15.0
# seed:5, v:20.0
# seed:5, v:25.0
# seed:5, v:30.0
# seed:5, v:35.0
# seed:5, v:40.0
# seed:5, v:45.0
# seed:5, v:50.0
# seed:5, v:55.0
# seed:5, v:60.0
# seed:5, v:15.0
# seed:5, v:20.0
# seed:5, v:25.0
# seed:5, v:30.0
# seed:5, v:35.0
# seed:5, v:40.0
# seed:5, v:45.0
# seed:5, v:50.0
# seed:5, v:55.0
# seed:5, v:60.0
# seed:6, v:15.0
# seed:6, v:20.0
# seed:6, v:25.0
# seed:6, v:30.0
# seed:6, v:35.0
# seed:6, v:40.0
# seed:6, v:45.0
# seed:6, v:50.0
# seed:6, v:55.0
# seed:6, v:60.0
# seed:6, v:15.0
# seed:6, v:20.0
# seed:6, v:25.0
# seed:6, v:30.0
# seed:6, v:35.0
# seed:6, v:40.0
# seed:6, v:45.0
# seed:6, v:50.0
# seed:6, v:55.0
# seed:6, v:60.0
# seed:6, v:15.0
# seed:6, v:20.0
# seed:6, v:25.0
# seed:6, v:30.0
# seed:6, v:35.0
# seed:6, v:40.0
# seed:6, v:45.0
# seed:6, v:50.0
# seed:6, v:55.0
# seed:6, v:60.0
# seed:6, v:15.0
# seed:6, v:20.0
# seed:6, v:25.0
# seed:6, v:30.0
# seed:6, v:35.0
# seed:6, v:40.0
# seed:6, v:45.0
# seed:6, v:50.0
# seed:6, v:55.0
# seed:6, v:60.0
# seed:7, v:20.0
# seed:7, v:25.0
# seed:7, v:30.0
# seed:7, v:35.0
# seed:7, v:40.0
# seed:7, v:45.0
# seed:7, v:50.0
# seed:7, v:55.0
# seed:7, v:60.0
# seed:7, v:15.0
# seed:7, v:20.0
# seed:7, v:25.0
# seed:7, v:30.0
# seed:7, v:35.0
# seed:7, v:40.0
# seed:7, v:45.0
# seed:7, v:50.0
# seed:7, v:55.0
# seed:7, v:60.0
# seed:7, v:15.0
# seed:7, v:20.0
# seed:7, v:25.0
# seed:7, v:30.0
# seed:7, v:35.0
# seed:7, v:40.0
# seed:7, v:45.0
# seed:7, v:50.0
# seed:7, v:55.0
# seed:7, v:60.0
# seed:7, v:15.0
# seed:7, v:20.0
# seed:7, v:25.0
# seed:7, v:30.0
# seed:7, v:35.0
# seed:7, v:40.0
# seed:7, v:45.0
# seed:7, v:50.0
# seed:7, v:55.0
# seed:7, v:60.0
# seed:8, v:15.0
# seed:8, v:20.0
# seed:8, v:25.0
# seed:8, v:30.0
# seed:8, v:35.0
# seed:8, v:40.0
# seed:8, v:45.0
# seed:8, v:50.0
# seed:8, v:55.0
# seed:8, v:60.0
# seed:8, v:15.0
# seed:8, v:20.0
# seed:8, v:25.0
# seed:8, v:30.0
# seed:8, v:35.0
# seed:8, v:40.0
# seed:8, v:45.0
# seed:8, v:50.0
# seed:8, v:55.0
# seed:8, v:60.0
# seed:8, v:15.0
# seed:8, v:20.0
# seed:8, v:25.0
# seed:8, v:30.0
# seed:8, v:35.0
# seed:8, v:40.0
# seed:8, v:45.0
# seed:8, v:50.0
# seed:8, v:55.0
# seed:8, v:60.0
# seed:8, v:15.0
# seed:8, v:20.0
# seed:8, v:25.0
# seed:8, v:30.0
# seed:8, v:35.0
# seed:8, v:40.0
# seed:8, v:45.0
# seed:8, v:50.0
# seed:8, v:55.0
# seed:8, v:60.0
# seed:9, v:30.0
# seed:9, v:35.0
# seed:9, v:40.0
# seed:9, v:45.0
# seed:9, v:50.0
# seed:9, v:55.0
# seed:9, v:60.0
# seed:9, v:30.0
# seed:9, v:35.0
# seed:9, v:40.0
# seed:9, v:45.0
# seed:9, v:50.0
# seed:9, v:55.0
# seed:9, v:60.0
# seed:9, v:15.0
# seed:9, v:20.0
# seed:9, v:25.0
# seed:9, v:30.0
# seed:9, v:35.0
# seed:9, v:40.0
# seed:9, v:45.0
# seed:9, v:50.0
# seed:9, v:55.0
# seed:9, v:60.0
# seed:9, v:15.0
# seed:9, v:20.0
# seed:9, v:25.0
# seed:9, v:30.0
# seed:9, v:35.0
# seed:9, v:40.0
# seed:9, v:45.0
# seed:9, v:50.0
# seed:9, v:55.0
# seed:9, v:60.0
# seed:10, v:15.0
# seed:10, v:20.0
# seed:10, v:25.0
# seed:10, v:30.0
# seed:10, v:35.0
# seed:10, v:40.0
# seed:10, v:45.0
# seed:10, v:50.0
# seed:10, v:55.0
# seed:10, v:60.0
# seed:10, v:15.0
# seed:10, v:20.0
# seed:10, v:25.0
# seed:10, v:30.0
# seed:10, v:35.0
# seed:10, v:40.0
# seed:10, v:45.0
# seed:10, v:50.0
# seed:10, v:55.0
# seed:10, v:60.0
# seed:10, v:15.0
# seed:10, v:20.0
# seed:10, v:25.0
# seed:10, v:30.0
# seed:10, v:35.0
# seed:10, v:40.0
# seed:10, v:45.0
# seed:10, v:50.0
# seed:10, v:55.0
# seed:10, v:60.0
# seed:10, v:15.0
# seed:10, v:20.0
# seed:10, v:25.0
# seed:10, v:30.0
# seed:10, v:35.0
# seed:10, v:40.0
# seed:10, v:45.0
# seed:10, v:50.0
# seed:10, v:55.0
# seed:10, v:60.0
# seed:11, v:20.0
# seed:11, v:25.0
# seed:11, v:30.0
# seed:11, v:35.0
# seed:11, v:40.0
# seed:11, v:45.0
# seed:11, v:50.0
# seed:11, v:55.0
# seed:11, v:60.0
# seed:11, v:15.0
# seed:11, v:20.0
# seed:11, v:25.0
# seed:11, v:30.0
# seed:11, v:35.0
# seed:11, v:40.0
# seed:11, v:45.0
# seed:11, v:50.0
# seed:11, v:55.0
# seed:11, v:60.0
# seed:11, v:15.0
# seed:11, v:20.0
# seed:11, v:25.0
# seed:11, v:30.0
# seed:11, v:35.0
# seed:11, v:40.0
# seed:11, v:45.0
# seed:11, v:50.0
# seed:11, v:55.0
# seed:11, v:60.0
# seed:11, v:15.0
# seed:11, v:20.0
# seed:11, v:25.0
# seed:11, v:30.0
# seed:11, v:35.0
# seed:11, v:40.0
# seed:11, v:45.0
# seed:11, v:50.0
# seed:11, v:55.0
# seed:11, v:60.0
# seed:12, v:20.0
# seed:12, v:25.0
# seed:12, v:30.0
# seed:12, v:35.0
# seed:12, v:40.0
# seed:12, v:45.0
# seed:12, v:50.0
# seed:12, v:55.0
# seed:12, v:60.0
# seed:12, v:15.0
# seed:12, v:20.0
# seed:12, v:25.0
# seed:12, v:30.0
# seed:12, v:35.0
# seed:12, v:40.0
# seed:12, v:45.0
# seed:12, v:50.0
# seed:12, v:55.0
# seed:12, v:60.0
# seed:12, v:15.0
# seed:12, v:20.0
# seed:12, v:25.0
# seed:12, v:30.0
# seed:12, v:35.0
# seed:12, v:40.0
# seed:12, v:45.0
# seed:12, v:50.0
# seed:12, v:55.0
# seed:12, v:60.0
# seed:12, v:15.0
# seed:12, v:20.0
# seed:12, v:25.0
# seed:12, v:30.0
# seed:12, v:35.0
# seed:12, v:40.0
# seed:12, v:45.0
# seed:12, v:50.0
# seed:12, v:55.0
# seed:12, v:60.0
# seed:13, v:15.0
# seed:13, v:20.0
# seed:13, v:25.0
# seed:13, v:30.0
# seed:13, v:35.0
# seed:13, v:40.0
# seed:13, v:45.0
# seed:13, v:50.0
# seed:13, v:55.0
# seed:13, v:60.0
# seed:13, v:15.0
# seed:13, v:20.0
# seed:13, v:25.0
# seed:13, v:30.0
# seed:13, v:35.0
# seed:13, v:40.0
# seed:13, v:45.0
# seed:13, v:50.0
# seed:13, v:55.0
# seed:13, v:60.0
# seed:13, v:15.0
# seed:13, v:20.0
# seed:13, v:25.0
# seed:13, v:30.0
# seed:13, v:35.0
# seed:13, v:40.0
# seed:13, v:45.0
# seed:13, v:50.0
# seed:13, v:55.0
# seed:13, v:60.0
# seed:13, v:15.0
# seed:13, v:20.0
# seed:13, v:25.0
# seed:13, v:30.0
# seed:13, v:35.0
# seed:13, v:40.0
# seed:13, v:45.0
# seed:13, v:50.0
# seed:13, v:55.0
# seed:13, v:60.0
# seed:14, v:15.0
# seed:14, v:20.0
# seed:14, v:25.0
# seed:14, v:30.0
# seed:14, v:35.0
# seed:14, v:40.0
# seed:14, v:45.0
# seed:14, v:50.0
# seed:14, v:55.0
# seed:14, v:60.0
# seed:14, v:15.0
# seed:14, v:20.0
# seed:14, v:25.0
# seed:14, v:30.0
# seed:14, v:35.0
# seed:14, v:40.0
# seed:14, v:45.0
# seed:14, v:50.0
# seed:14, v:55.0
# seed:14, v:60.0
# seed:14, v:15.0
# seed:14, v:20.0
# seed:14, v:25.0
# seed:14, v:30.0
# seed:14, v:35.0
# seed:14, v:40.0
# seed:14, v:45.0
# seed:14, v:50.0
# seed:14, v:55.0
# seed:14, v:60.0
# seed:14, v:15.0
# seed:14, v:20.0
# seed:14, v:25.0
# seed:14, v:30.0
# seed:14, v:35.0
# seed:14, v:40.0
# seed:14, v:45.0
# seed:14, v:50.0
# seed:14, v:55.0
# seed:14, v:60.0
# seed:15, v:15.0
# seed:15, v:20.0
# seed:15, v:25.0
# seed:15, v:30.0
# seed:15, v:35.0
# seed:15, v:40.0
# seed:15, v:45.0
# seed:15, v:50.0
# seed:15, v:55.0
# seed:15, v:60.0
# seed:15, v:15.0
# seed:15, v:20.0
# seed:15, v:25.0
# seed:15, v:30.0
# seed:15, v:35.0
# seed:15, v:40.0
# seed:15, v:45.0
# seed:15, v:50.0
# seed:15, v:55.0
# seed:15, v:60.0
# seed:15, v:15.0
# seed:15, v:20.0
# seed:15, v:25.0
# seed:15, v:30.0
# seed:15, v:35.0
# seed:15, v:40.0
# seed:15, v:45.0
# seed:15, v:50.0
# seed:15, v:55.0
# seed:15, v:60.0
# seed:15, v:15.0
# seed:15, v:20.0
# seed:15, v:25.0
# seed:15, v:30.0
# seed:15, v:35.0
# seed:15, v:40.0
# seed:15, v:45.0
# seed:15, v:50.0
# seed:15, v:55.0
# seed:15, v:60.0
# seed:16, v:15.0
# seed:16, v:20.0
# seed:16, v:25.0
# seed:16, v:30.0
# seed:16, v:35.0
# seed:16, v:40.0
# seed:16, v:45.0
# seed:16, v:50.0
# seed:16, v:55.0
# seed:16, v:60.0
# seed:16, v:15.0
# seed:16, v:20.0
# seed:16, v:25.0
# seed:16, v:30.0
# seed:16, v:35.0
# seed:16, v:40.0
# seed:16, v:45.0
# seed:16, v:50.0
# seed:16, v:55.0
# seed:16, v:60.0
# seed:16, v:15.0
# seed:16, v:20.0
# seed:16, v:25.0
# seed:16, v:30.0
# seed:16, v:35.0
# seed:16, v:40.0
# seed:16, v:45.0
# seed:16, v:50.0
# seed:16, v:55.0
# seed:16, v:60.0
# seed:16, v:15.0
# seed:16, v:20.0
# seed:16, v:25.0
# seed:16, v:30.0
# seed:16, v:35.0
# seed:16, v:40.0
# seed:16, v:45.0
# seed:16, v:50.0
# seed:16, v:55.0
# seed:16, v:60.0
# seed:17, v:15.0
# seed:17, v:20.0
# seed:17, v:25.0
# seed:17, v:30.0
# seed:17, v:35.0
# seed:17, v:40.0
# seed:17, v:45.0
# seed:17, v:50.0
# seed:17, v:55.0
# seed:17, v:60.0
# seed:17, v:15.0
# seed:17, v:20.0
# seed:17, v:25.0
# seed:17, v:30.0
# seed:17, v:35.0
# seed:17, v:40.0
# seed:17, v:45.0
# seed:17, v:50.0
# seed:17, v:55.0
# seed:17, v:60.0
# seed:17, v:15.0
# seed:17, v:20.0
# seed:17, v:25.0
# seed:17, v:30.0
# seed:17, v:35.0
# seed:17, v:40.0
# seed:17, v:45.0
# seed:17, v:50.0
# seed:17, v:55.0
# seed:17, v:60.0
# seed:17, v:15.0
# seed:17, v:20.0
# seed:17, v:25.0
# seed:17, v:30.0
# seed:17, v:35.0
# seed:17, v:40.0
# seed:17, v:45.0
# seed:17, v:50.0
# seed:17, v:55.0
# seed:17, v:60.0
# seed:18, v:20.0
# seed:18, v:25.0
# seed:18, v:30.0
# seed:18, v:35.0
# seed:18, v:40.0
# seed:18, v:45.0
# seed:18, v:50.0
# seed:18, v:55.0
# seed:18, v:60.0
# seed:18, v:20.0
# seed:18, v:25.0
# seed:18, v:30.0
# seed:18, v:35.0
# seed:18, v:40.0
# seed:18, v:45.0
# seed:18, v:50.0
# seed:18, v:55.0
# seed:18, v:60.0
# seed:18, v:15.0
# seed:18, v:20.0
# seed:18, v:25.0
# seed:18, v:30.0
# seed:18, v:35.0
# seed:18, v:40.0
# seed:18, v:45.0
# seed:18, v:50.0
# seed:18, v:55.0
# seed:18, v:60.0
# seed:18, v:15.0
# seed:18, v:20.0
# seed:18, v:25.0
# seed:18, v:30.0
# seed:18, v:35.0
# seed:18, v:40.0
# seed:18, v:45.0
# seed:18, v:50.0
# seed:18, v:55.0
# seed:18, v:60.0
# seed:19, v:25.0
# seed:19, v:30.0
# seed:19, v:35.0
# seed:19, v:40.0
# seed:19, v:45.0
# seed:19, v:50.0
# seed:19, v:55.0
# seed:19, v:60.0
# seed:19, v:25.0
# seed:19, v:30.0
# seed:19, v:35.0
# seed:19, v:40.0
# seed:19, v:45.0
# seed:19, v:50.0
# seed:19, v:55.0
# seed:19, v:60.0
# seed:19, v:15.0
# seed:19, v:20.0
# seed:19, v:25.0
# seed:19, v:30.0
# seed:19, v:35.0
# seed:19, v:40.0
# seed:19, v:45.0
# seed:19, v:50.0
# seed:19, v:55.0
# seed:19, v:60.0
# seed:19, v:15.0
# seed:19, v:20.0
# seed:19, v:25.0
# seed:19, v:30.0
# seed:19, v:35.0
# seed:19, v:40.0
# seed:19, v:45.0
# seed:19, v:50.0
# seed:19, v:55.0
# seed:19, v:60.0
# ub:lbd0u, mean:14.465864599943162
# ub:lbd1u, mean:33.52955315947533
# ub:lbd2u, mean:176.13189919471742
# ub:lbd3u, mean:200.71851427674292
# count:1/5 youtube_1000_T.pdf completed.
# count:2/5 youtube_v.jpg completed.
# count:3/5 youtube_v.jpg completed.

# %% [markdown]
# youtube:
# ub:ub1m, mean:14.431588050978524
# ub:ub1ma, mean:11.808049839087895
# facebook:
# ub:ub1m, mean:38.45848848077229
# ub:ub1ma, mean:32.959769962447034
# adult:
# ub:ub1m, mean:12.760346107891628
# ub:ub1ma, mean:10.346145006758826
# caltech:
# ub:ub1m, mean:7.05343784563882
# ub:ub1ma, mean:6.203636246136257
